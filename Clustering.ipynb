# %%
# This file is for testing out the k-means clustering
import matplotlib.pyplot as plt 
import numpy
from sklearn.cluster import KMeans



import random 
x = []
y = []
z = []
for i in range(30): x.append(numpy.round(random.random() *100, 0))
for i in range(30): y.append(numpy.round(random.random() *100, 0))
for i in range(30): z.append(numpy.round(random.random() *100, 0))

fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(x, y, z, cmap = 'Greens');

# %%
import pandas as pd

dict = {"x":x, "y": y, "z": z}

df = pd.DataFrame(dict)
Y = zip(x, y, z)
X = numpy.array(list(Y))

km = KMeans(5)
clusts = km.fit_predict(X)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1],
            km.cluster_centers_[:, 2],
            s = 250,
            marker='o',
            c='red',
            label='centroids')
scatter = ax.scatter(df['x'],df['y'], df['z'],
                     c=clusts,s=20, cmap='winter')
# Out:
# [[73.5        87.75       17.25      ]
#  [22.4        30.8        85.        ]
#  [65.14285714 67.85714286 74.        ]
#  [22.75       45.5        24.        ]
#  [73.3        28.4        25.2       ]]

# %%
km = KMeans(3)
clusts = km.fit_predict(X)

# %%
data = list(zip(x, y))
inertias = []

for i in range(1, 11): 
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1, 11), inertias, marker = 'o') 
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()

# %%
# All I particularily need is a way to quantify the basketball players. Now one way to do this is by 
# Points, Steals, Rebounds, which are the three main stats that are used in basketball. 
# It would make it easier to what exactly lmao. Well easier to hmmm... observe! Yes that's the word
# observe, as it is a 3 dimensional area, within which we can visualize orbs quite easily.
